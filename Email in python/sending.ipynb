# %% [markdown]
# sending emials through python

# %%
import smtplib

# %%
smtp_obj = smtplib.SMTP('smtp.gmail.com' , 587)

# %%
smtp_obj.ehlo()
# Out:
# (250,
#  b'smtp.gmail.com at your service, [182.64.251.111]\nSIZE 35882577\n8BITMIME\nSTARTTLS\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8')

# %%
smtp_obj.starttls()
# Out:
# (220, b'2.0.0 Ready to start TLS')

# %%
import getpass

# %%
password = getpass.getpass('what is ur password' )

# %%
email= getpass.getpass("Email : ")
password = getpass.getpass("password: ")
smtp_obj.login(email, password)
